Hello, mindfulness seekers! I'm Luna, a meditation guide dedicated to helping others find inner peace and balance in their lives. Through guided meditation sessions and mindfulness practices, I empower individuals to embrace the present moment and cultivate a sense of calm. When I'm not guiding others on their mindfulness journey, I enjoy practicing yoga and immersing myself in nature's serenity. Let's embark on a virtual voyage of self-discovery and tranquility!

"""

# %%
import pandas as pd

# Split the string into a list of descriptions
descriptions = string_with_descriptions.split('\n\n')

# Create a list to store the word count for each description
word_counts = []
letter_counts = []

# # Count the number of words in each description
# for desc in descriptions:
#     word_count = len(desc.split())
#     word_counts.append(word_count)
# Count the number of letters in each description
for desc in descriptions:
    letter_count = len(desc)
    letter_counts.append(letter_count)

# Create a DataFrame from the list
df = pd.DataFrame({'description': descriptions, 'letter_count': letter_counts})

# %%
df
# Out:
#                                           description  letter_count
# 0   Greetings, everyone! I go by the name Maxine, ...           282
# 1   Hello, folks! I'm Oscar, a thrill-seeking adve...           357
# 2   Salutations, everyone! My name is Celeste, and...           374
# 3   Hey there, amigos! I'm Diego, a charismatic sa...           390
# 4   Greetings, fellow bookworms! I'm Penelope, an ...           394
# 5   Hi, everyone! I'm Rajiv, a tech guru hailing f...           364
# 6   Namaste, friends! I'm Aisha, a passionate wild...           390
# 7   Hey, y'all! I'm Wyatt, a charismatic rodeo cow...           317
# 8   Hello, everyone! I'm Sakura, a talented sushi ...           359
# 9   Greetings, fellow adrenaline junkies! I'm Alex...           406
# 10  Hey there, amigos! I'm Isabella, a vibrant fla...           381
# 11  Greetings, fellow earthlings! I'm Xander, an e...           426
# 12  Salutations, everyone! I'm Aurora, a graceful ...           353
# ...

# %%
def reword(sentence):
    return '.'.join(sentence.split('.')[:-1])

# %%
descriptions = df.apply(lambda x: x.description if x.letter_count < 390 else reword(x.description),axis=1).tolist()

# Create a list to store the word count for each description
word_counts = []
letter_counts = []

# # Count the number of words in each description
# for desc in descriptions:
#     word_count = len(desc.split())
#     word_counts.append(word_count)
# Count the number of letters in each description
for desc in descriptions:
    letter_count = len(desc)
    letter_counts.append(letter_count)

# Create a DataFrame from the list
new_df = pd.DataFrame({'description': descriptions, 'letter_count': letter_counts})

# %%
new_df = new_df[(new_df['letter_count'] <= 399) & (new_df['letter_count'] > 0)]

# %%
new_df.to_csv('fowosere.csv',index=False)

# %%
import pandas as pd
dd = pd.read_excel('fowosere (2).xlsx')
dd['letter_count'] = dd.description.apply(lambda x:len(x))

# %%
def reword(sentence):
    return '.'.join(sentence.split('.')[:-1])

dd['description'] = dd.apply(lambda x: x.description if x.letter_count < 390 else reword(x.description),axis=1).tolist()
dd['letter_count'] = dd.description.apply(lambda x:len(x))
dd[dd['letter_count'] > 390]
# Out:
# Empty DataFrame
# Columns: [description, name, country, letter_count]
# Index: []

# %%
dd.to_csv('fowosere.csv',index=False)
